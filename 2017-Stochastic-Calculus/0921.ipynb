# %% [markdown]
# 2017.09.21 Stochastic Calculus - Gipyo Bae

# %% [markdown]
# ## Stochastic Process
#  $$X: \Omega \times [0,T] = {(w,t) : w \in \Omega, t \in [0,T]}$$
#  $$x(\bullet,t) : \mathcal{F}_-measurable  $$
#  $$ \mathcal{F}_ = (\mathcal{F}_{t})^T_{t=0}$$   (sigma algebra increasing as t increses)
# (Cartesian Product To Real Number)

# %% [markdown]
# #### View Point 1
# : a collection of random variables
# <ul>
#      Let $t\in[0,T]$,  $X_{t} = X(\bullet,t) :  \Omega \rightarrow \mathbb{R}$
#          $$X_{t}(w) = X(w,t)$$
#      $${X(\bullet,t)}_{t\in[0,T]}\space\space: \mathcal{F}-measurable $$
#      </ul>
#      $* \mathcal{F}_{T}$ measurable : weaker condition as T increases

# %% [markdown]
# #### View Point 2
# :a Collection of all possible path
# <ul>
# Let $w \in \Omega , X(W,\bullet) : [0,T] \rightarrow \mathbb{R}$
#     $$X(w,\bullet)(t) \equiv X(w,t)$$
# </ul>

# %% [markdown]
# ### $X = (X_{t})$ is ${\mathcal{F}_{t}}$ : Adapted
# $\Leftrightarrow X_{t}$ is $\mathcal{F}_{t}$-measurable $\forall t \in [0,T]$

# %% [markdown]
# ### $X$ is $\mathcal{F}$ predictable
# $\Leftrightarrow X_{t}$ is $\mathcal{F}_{t-}$ measurable $\forall t \in [0,T]$
# $\mathcal{F}_{t-} \in \cup_{S\in[0,t]}F_{s}$
# $*adapted \Rightarrow predictable$
#   adaptef $\nLeftarrow predictable$
# $*\mathcal{F}\subset G$
# $X : \mathcal{F}$ measurable $\rightarrow X : G$ measurable

# %% [markdown]
# ## Conditional Expectaion
# $\circ \space E(X_{u}\mid \mathcal{F}_{t}) \space (u>t>s>0)  $
# $$E[E(X_{u}\mid \mathcal{F}_{t})\mid F_{s}] = E[X_{u} \mid \mathcal{F}_{s}]$$
# $$E[X_{u} \mid \mathcal{F}_{0}] = E[X_{u}]$$
# :tower property
# :the law of iterated expectation

# %% [markdown]
# ### $X = (X_{t})$ : a martingale
# $$ \forall t\leq u, E[X_{u}\mid \mathcal{F}_{t}] =\star\space X_{t}$$
# ($\star\space\leq$ for super martingale, $\geq$ for sub martingale)

# %% [markdown]
# #### Ex.
# $\circ \space A$(event) has occured $\Leftrightarrow w \in A$
# $\circ \space X_{t}$ is $\mathcal{F}_{t}$ measurable
# $\Rightarrow$ 100<$X_{t} = X_{t}^{-1}((100, \infty)) \in \mathcal{F}_{t}$
# $\circ \space X_{t+1}$ is not $\mathcal{F}_{t}$ measurable

# %% [markdown]
# ### $H_{t}$ is generated by ($X_{t})$
# $\Leftrightarrow H$ is the smallest filtration such that $X_{t}$ is $H$-adapted

# %% [markdown]
# ## Brownian Motions
# $$B : \Omega \times [0,\infty) \rightarrow \mathbb{R}$$
# 1. $B(w,0) = 0 \forall w \in \Omega$
# 2. $B_{t} \sim N(0,t)$
# 3. $t_{0} < t_{1} < t_{2} < ...< t_{N}$
# $B_{t}-B_{t_{N-1}},..., B_{t_{2}}-B_{t_{1}},B{t_{1}}-B_{t_{0}}$are statistically independant
# $\circ$ Norbat Wienet가 실제로 Construct 했다.
# ### Wiener Process (\Omega, \mathcal{A}, P) := the other name of brownian motion
# $\circ$ For continuous process
# $$B:\Omega \times [0,T]$$
# $$C[0,T] = \{ f : [0,T] \rightarrow \mathbb{R}, f:continuos \}$$
# $\Omega = C[0,T:0] = \{f \in [0,T],f(0) = 0\}$
# $\mathcal{A} : \sigma$-algebra set generated by random walk
# $P$ : the probability of each path. random walk

# %% [markdown]
# [Homework]
# $X_{t+i}$
# =$X_{t} + sqrt(\bigtriangleup t)$ for p = 0.5
# $\space X_{t} - sqrt(\bigtriangleup t)$ for p = 0.5
# $(X_{0} = 0 , \bigtriangleup t = t/N)$
# Figure out the movements of $X_{t}\space as\space \bigtriangleup t \rightarrow \infty$ on random walk
# $\circ almost\space surely : $ when $ almost\space everywhere$  satisfied on probability space

# %% [markdown]
# [Properties for next class]
# 1.Simple path are nowhere diffrentiable a.s.
# 2.Total variation of Brownian motion over [a,b] (a<b) is $\infty$
